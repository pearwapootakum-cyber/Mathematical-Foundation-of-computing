# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.26.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/miniconda3/envs/python2/lib/python3.14/site-packages (from scikit-image) (2.3.5)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting networkx>=3.0 (from scikit-image)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pillow>=10.1 in /opt/miniconda3/envs/python2/lib/python3.14/site-packages (from scikit-image) (12.1.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Using cached imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2026.2.15-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in /opt/miniconda3/envs/python2/lib/python3.14/site-packages (from scikit-image) (25.0)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.26.0-cp314-cp314-macosx_11_0_arm64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 11.7 MB/s  0:00:01 eta 0:00:01
# Using cached imageio-2.37.2-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.9 MB/s  0:00:00
# Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 15.3 MB/s  0:00:01m0:00:0100:01
# Downloading tifffile-2026.2.15-py3-none-any.whl (233 kB)
# Installing collected packages: tifffile, scipy, networkx, lazy-loader, imageio, scikit-image
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [scikit-image] [scikit-image]
# Successfully installed imageio-2.37.2 lazy-loader-0.4 networkx-3.6.1 scikit-image-0.26.0 scipy-1.17.0 tifffile-2026.2.15

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, color, filters, measure

# %%
image_pixels = io.imread("images/manyhearts1.jpg")
image_pixels.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 image_pixels = io.imread("images/manyhearts1.jpg")
#       2 image_pixels.shape
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/skimage/_shared/utils.py:386, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     382     elif self.new_name is not None:
#     383         # Assign old value to new one
#     384         kwargs[self.new_name] = deprecated_value
# --> 386 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/skimage/io/_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/skimage/_shared/utils.py:690, in deprecate_func.__call__.<locals>.wrapped(*args, **kwargs)
#     684 stacklevel = (
#     685     self.stacklevel
#     686     if self.stacklevel is not None
#     687     else _warning_stacklevel(func)
#     688 )
#     689 warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 690 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/skimage/io/manage_plugins.py:254, in call_plugin(kind, *args, **kwargs)
#     251     except IndexError:
#     252         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 254 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/skimage/io/_plugins/imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/imageio/v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/imageio/core/request.py:250, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     247     raise ValueError(f"Invalid Request.Mode: {mode}")
#     249 # Parse what was given
# --> 250 self._parse_uri(uri)
#     252 # Set extension
#     253 if extension is not None:
#
# File /opt/miniconda3/envs/python2/lib/python3.14/site-packages/imageio/core/request.py:410, in Request._parse_uri(self, uri)
#     407 if is_read_request:
#     408     # Reading: check that the file exists (but is allowed a dir)
#     409     if not os.path.exists(fn):
# --> 410         raise FileNotFoundError("No such file: '%s'" % fn)
#     411 else:
#     412     # Writing: check that the directory to write to does exist
#     413     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/Users/thanaporn/Desktop/Math of computing/classwork/sobel/images/manyhearts1.jpg'

# %%
if image_pixels.shape[-1] == 4:
    image_pixels = image_pixels[..., :3]  # discard alpha

# %%
gray_img = color.rgb2gray(image_pixels)
plt.imshow(gray_img, cmap="gray")
plt.axis("off")
plt.show()

# %%
edge_sobel = filters.sobel(gray_img)
edge_sobel.shape

# %%
from skimage.util import img_as_ubyte

io.imsave("images/edge_sobel.png", img_as_ubyte(edge_sobel))

plt.imshow(edge_sobel, cmap="gray")
plt.axis("off")
plt.show()

# %%
threshold = 0.2
edges = edge_sobel > threshold
edges[30:33,:30]

# %%
edge_pixel_indices = np.nonzero(edges)
edge_pixel_indices

# %%
edges[104,572]

# %%
edge_points = np.column_stack(np.nonzero(edges))
edge_points[:3]

# %%
contours = measure.find_contours(edges, level=0.5)
contours
